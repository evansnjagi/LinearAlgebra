# %% [markdown]
# ## Understand the data

# %% [markdown]
# ## Load the data

# %%
# Modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the mall dataset
filepath = "../data/Mall Customers.xlsx"

df = pd.read_excel(filepath)

# Show the first rows
df.head()
# Out:
#    CustomerID Gender  Age   Education  Marital Status  Annual Income (k$)  \
# 0           1      M   19  High School        Married                  15
# 1           2      M   21     Graduate         Single                  15
# 2           3      F   20     Graduate        Married                  16
# 3           4      F   23  High School        Unknown                  16
# 4           5      F   31   Uneducated        Married                  17
#
#    Spending Score (1-100)
# 0                      39
# 1                      81
# 2                       6
# 3                      77
# 4                      40

# %% [markdown]
# ## Understand the data structure

# %%
# Shape
print("Shape: ", df.shape)

# Columns
print('\n Columns: ', end="")
print(df.columns.tolist())
# Out:
# Shape:  (200, 7)
#
#  Columns: ['CustomerID', 'Gender', 'Age', 'Education ', 'Marital Status', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
# Info
print("\n Info: ")
print(df.info())
# Out:
#  Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    str
#  2   Age                     200 non-null    int64
#  3   Education               200 non-null    str
#  4   Marital Status          200 non-null    str
#  5   Annual Income (k$)      200 non-null    int64
#  6   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), str(3)
# memory usage: 11.1 KB
# None

# %%
# Missing data
print("\n Missing values: ")
print(df.isnull().sum())
# Out:
#  Missing values:
# CustomerID                0
# Gender                    0
# Age                       0
# Education                 0
# Marital Status            0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# # Business requirements
#
# 1. How many customers are there?
# 2. Which columns\features are numerical?
# 3. Which columns\features are categorical?
# 4. Which columns will be useful in customer segmentation?
# 5. Any missing data?
# 6. How many features are there?

# %% [markdown]
# # Conclusion
#
# The dataset has 200 customers with 6 features each.
#
# There are no missing values.
#
# The following are the categorical variables present in the dataset:
#     1. Marital status
#     2. Education
#     3. Gender
#
# There are numerical variables as well, they includes:
#     1. CustomerId
#     2. Annual Income
#     3. Spending score
#     4. Age
#
# CustomerId feature is a redundant feature so we are going to drop it. Age, Annual income and Spending score features will be our vectors and matrix.
